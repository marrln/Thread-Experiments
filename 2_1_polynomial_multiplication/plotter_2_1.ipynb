# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

component_labels = {
    'time_alloc': 'Alloc', 'time_init': 'Init', 'time_thread_create': 'Thread Create',
    'time_compute': 'Compute', 'time_join': 'Join', 'time_reduce': 'Reduce',
    'time_cleanup': 'Cleanup'
}

res_1_df = pd.read_csv('results_2.1.csv')
# Preserve original threads label (so 'sequential' isn't lost) and create numeric threads for plotting
res_1_df['threads_label'] = res_1_df['threads'].astype(str)

def threads_to_int(x):
    if str(x).lower() == 'sequential':
        return -1
    try:
        return int(x)
    except Exception:
        return 1

res_1_df['threads'] = res_1_df['threads_label'].apply(threads_to_int)

os.makedirs('plots', exist_ok=True)

for selected_user in res_1_df['user'].unique():
    user_data = res_1_df[res_1_df['user'] == selected_user]
    degrees = sorted(user_data['degree'].unique())
    
    fig, axes = plt.subplots(2, 2, figsize=(8, 8))
    axes = axes.flatten()
    
    for idx, degree in enumerate(degrees):
        degree_data = user_data[user_data['degree'] == degree].copy()
        
        degree_data['effective_total'] = degree_data['time_total'] - degree_data['time_verify']
        # Compute mean and std across runs per threads
        example_mean = degree_data.groupby('threads').mean(numeric_only=True).reset_index()
        example_std = degree_data.groupby('threads').std(numeric_only=True).reset_index().fillna(0)
        
        example_mean['threads_sort'] = example_mean['threads'].apply(
            lambda x: -1 if x == 'sequential' else int(x)
        )
        example_mean = example_mean.sort_values('threads_sort').reset_index(drop=True)
        example_std = example_std.set_index('threads').reindex(example_mean['threads']).reset_index(drop=True)
        
        ax = axes[idx]
        x_positions = np.arange(len(example_mean))
        
        bottom = np.zeros(len(example_mean))
        available_components = [c for c in component_labels if c in example_mean.columns]
        
        for component in available_components:
            values = example_mean[component].values
            errs = example_std[component].values if component in example_std.columns else np.zeros_like(values)
            ax.bar(x_positions, values, bottom=bottom, yerr=errs, capsize=3, label=component_labels[component], 
                   alpha=0.85, width=0.6)
            bottom += values
        
        components_sum = example_mean[available_components].sum(axis=1).values
        remaining = example_mean['effective_total'].values - components_sum
        remaining_err = example_std['time_total'].values if 'time_total' in example_std.columns else np.zeros_like(remaining)
        
        if np.any(remaining > 0.001):
            ax.bar(x_positions, remaining, bottom=bottom, yerr=remaining_err, capsize=3, label='Other/Overhead', 
                   alpha=0.85, width=0.6, color='gray')
        
        ax.set_xlabel('Number of Threads')
        ax.set_ylabel('Time (seconds)')
        ax.set_title(f'Degree = {int(degree)}')
        ax.set_xticks(x_positions)
        tick_labels = example_mean['threads'].apply(lambda x: 'sequential' if int(x) == -1 else str(int(x)))
        ax.set_xticklabels(tick_labels)
        if idx == 0:
            ax.legend(fontsize=8)
        ax.grid(True, alpha=0.3, axis='y')
    
    fig.suptitle(f'Timing Breakdown per Degree (User = {selected_user})', fontsize=16)
    plt.tight_layout()
    plt.savefig(f'plots/timing_breakdown_all_degrees_{selected_user}.png', dpi=300)
    plt.show()

sequential_data = res_1_df[res_1_df['threads_label'] == 'sequential']
baselines = sequential_data.groupby(['user', 'degree'])['time_total'].agg(['mean', 'std']).reset_index()
baselines.columns = ['user', 'degree', 'baseline_mean', 'baseline_std']

parallel_data = res_1_df[res_1_df['threads_label'] != 'sequential'].copy()
parallel_data['par_time'] = parallel_data['time_total'] - parallel_data['time_verify']
parallel_data['threads'] = parallel_data['threads'].astype(int)

speedup_data = parallel_data.merge(baselines, on=['user', 'degree'])
speedup_data['speedup'] = speedup_data['baseline_mean'] / speedup_data['par_time']
speedup_data = speedup_data[['user', 'degree', 'threads', 'speedup']]

speedup_stats = speedup_data.groupby(['user', 'degree', 'threads'])['speedup'].agg(['mean', 'std']).reset_index()

for user in speedup_stats['user'].unique():
    user_stats = speedup_stats[speedup_stats['user'] == user]
    user_baselines = baselines[baselines['user'] == user]
    
    fig, ax = plt.subplots(figsize=(8, 8))
    
    degrees = sorted(user_stats['degree'].unique())
    jitter = np.linspace(-0.1, 0.1, len(degrees))
    
    for idx, degree in enumerate(degrees):
        degree_data = user_stats[user_stats['degree'] == degree]
        x_jitter = degree_data['threads'] + jitter[idx]
        ax.errorbar(x_jitter, degree_data['mean'], yerr=degree_data['std'],
                    marker='o', label=f'Degree {int(degree)}', capsize=5, alpha=0.8)
    
    ax.axhline(y=1.0, color='r', linestyle='--', alpha=0.5, label='No speedup (1.0x)')
    
    baseline_uncertainty = user_baselines['baseline_std'].mean() / user_baselines['baseline_mean'].mean()
    ax.axhspan(1.0 - baseline_uncertainty, 1.0 + baseline_uncertainty, 
               color='red', alpha=0.1, label='Sequential Uncertainty')
    
    ax.set_xlabel('Number of Threads')
    ax.set_ylabel('Speedup (times)')
    ax.set_title(f'Speedup vs Thread Count (User = {user})')
    ax.set_xticks(sorted(user_stats['threads'].unique()))
    ax.grid(True, alpha=0.3)
    ax.legend()
    plt.tight_layout()
    plt.savefig(f'plots/speedup_per_degree_{user}.png', dpi=300)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/pandas/core/ops/array_ops.py:220, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 try:
# --> 220     result = func(left, right)
#     221 except TypeError:
#
# File /usr/lib/python3/dist-packages/pandas/core/computation/expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File /usr/lib/python3/dist-packages/pandas/core/computation/expressions.py:131, in _evaluate_numexpr(op, op_str, a, b)
#     130 if result is None:
# --> 131     result = _evaluate_standard(op, op_str, a, b)
#     133 return result
#
# File /usr/lib/python3/dist-packages/pandas/core/computation/expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 38
#      35 for idx, degree in enumerate(degrees):
#      36     degree_data = user_data[user_data['degree'] == degree].copy()
# ---> 38     degree_data['effective_total'] = degree_data['time_total'] - degree_data['time_verify']
#      39     example_data = degree_data.groupby('threads').mean(numeric_only=True).reset_index()
#      41     example_data['threads_sort'] = example_data['threads'].apply(
#      42         lambda x: -1 if x == 'sequential' else int(x)
#      43     )
#
# File /usr/lib/python3/dist-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File /usr/lib/python3/dist-packages/pandas/core/arraylike.py:194, in OpsMixin.__sub__(self, other)
#     192 @unpack_zerodim_and_defer("__sub__")
#     193 def __sub__(self, other):
# --> 194     return self._arith_method(other, operator.sub)
#
# File /usr/lib/python3/dist-packages/pandas/core/series.py:5819, in Series._arith_method(self, other, op)
#    5817 def _arith_method(self, other, op):
#    5818     self, other = self._align_for_op(other)
# -> 5819     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File /usr/lib/python3/dist-packages/pandas/core/base.py:1381, in IndexOpsMixin._arith_method(self, other, op)
#    1378     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1380 with np.errstate(all="ignore"):
# -> 1381     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1383 return self._construct_result(result, name=res_name)
#
# File /usr/lib/python3/dist-packages/pandas/core/ops/array_ops.py:285, in arithmetic_op(left, right, op)
#     281     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     283     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     284     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 285     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     287 return res_values
#
# File /usr/lib/python3/dist-packages/pandas/core/ops/array_ops.py:229, in _na_arithmetic_op(left, right, op, is_cmp)
#     221 except TypeError:
#     222     if not is_cmp and (
#     223         left.dtype == object or getattr(right, "dtype", None) == object
#     224     ):
#    (...)
#     227         # Don't do this for comparisons, as that will handle complex numbers
#     228         #  incorrectly, see GH#32047
# --> 229         result = _masked_arith_op(left, right, op)
#     230     else:
#     231         raise
#
# File /usr/lib/python3/dist-packages/pandas/core/ops/array_ops.py:165, in _masked_arith_op(x, y, op)
#     163     # See GH#5284, GH#5035, GH#19448 for historical reference
#     164     if mask.any():
# --> 165         result[mask] = op(xrav[mask], yrav[mask])
#     167 else:
#     168     if not is_scalar(y):
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'
